# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:/Users/Akshitha/New folder/Meachine_learning_pratice/archive (4).zip")

# %%
df.head()
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# 0             Yes                  0           Low          Medium
# 1             Yes                  2        Medium          Medium
# 2             Yes                  2        Medium          Medium
# 3             Yes                  1        Medium          Medium
# 4             Yes                  3        Medium            High
#
#   School_Type Peer_Influence  Physical_Activity Learning_Disabilities  \
# 0      Public       Positive                  3                    No
# 1      Public       Negative                  4                    No
# 2      Public        Neutral                  4                    No
# 3      Public       Negative                  4                    No
# 4      Public        Neutral                  4                    No
#
#   Parental_Education_Level Distance_from_Home  Gender  Exam_Score
# 0              High School               Near    Male          67
# 1                  College           Moderate  Female          61
# 2             Postgraduate               Near    Male          74
# 3              High School           Moderate    Male          71
# 4                  College               Near  Female          70

# %%
df.drop(columns=["Access_to_Resources", "Extracurricular_Activities", "Motivation_Level", "Internet_Access"], inplace=True)

# %%
df.head()
# Out:
#    Hours_Studied  Attendance Parental_Involvement  Sleep_Hours  \
# 0             23          84                  Low            7
# 1             19          64                  Low            8
# 2             24          98               Medium            7
# 3             29          89                  Low            8
# 4             19          92               Medium            6
#
#    Previous_Scores  Tutoring_Sessions Family_Income Teacher_Quality  \
# 0               73                  0           Low          Medium
# 1               59                  2        Medium          Medium
# 2               91                  2        Medium          Medium
# 3               98                  1        Medium          Medium
# 4               65                  3        Medium            High
#
#   School_Type Peer_Influence  Physical_Activity Learning_Disabilities  \
# 0      Public       Positive                  3                    No
# 1      Public       Negative                  4                    No
# 2      Public        Neutral                  4                    No
# 3      Public       Negative                  4                    No
# 4      Public        Neutral                  4                    No
#
#   Parental_Education_Level Distance_from_Home  Gender  Exam_Score
# 0              High School               Near    Male          67
# 1                  College           Moderate  Female          61
# 2             Postgraduate               Near    Male          74
# 3              High School           Moderate    Male          71
# 4                  College               Near  Female          70

# %%
df.drop(columns=["Tutoring_Sessions", "Tutoring_Sessions", "Peer_Influence", "Physical_Activity"], inplace=True)

# %%
df.isnull().sum(
    
)
# Out:
# Hours_Studied                0
# Attendance                   0
# Parental_Involvement         0
# Sleep_Hours                  0
# Previous_Scores              0
# Family_Income                0
# Teacher_Quality             78
# School_Type                  0
# Learning_Disabilities        0
# Parental_Education_Level    90
# Distance_from_Home          67
# Gender                       0
# Exam_Score                   0
# dtype: int64

# %%
df.head()
# Out:
#    Hours_Studied  Attendance Parental_Involvement  Sleep_Hours  \
# 0             23          84                  Low            7
# 1             19          64                  Low            8
# 2             24          98               Medium            7
# 3             29          89                  Low            8
# 4             19          92               Medium            6
#
#    Previous_Scores Family_Income Teacher_Quality School_Type  \
# 0               73           Low          Medium      Public
# 1               59        Medium          Medium      Public
# 2               91        Medium          Medium      Public
# 3               98        Medium          Medium      Public
# 4               65        Medium            High      Public
#
#   Learning_Disabilities Parental_Education_Level Distance_from_Home  Gender  \
# 0                    No              High School               Near    Male
# 1                    No                  College           Moderate  Female
# 2                    No             Postgraduate               Near    Male
# 3                    No              High School           Moderate    Male
# 4                    No                  College               Near  Female
#
#    Exam_Score
# 0          67
# 1          61
# 2          74
# 3          71
# 4          70

# %%
df.drop(columns=["Teacher_Quality"], inplace=True)

# %%
df.head()
# Out:
#    Hours_Studied  Attendance Parental_Involvement  Sleep_Hours  \
# 0             23          84                  Low            7
# 1             19          64                  Low            8
# 2             24          98               Medium            7
# 3             29          89                  Low            8
# 4             19          92               Medium            6
#
#    Previous_Scores Family_Income School_Type Learning_Disabilities  \
# 0               73           Low      Public                    No
# 1               59        Medium      Public                    No
# 2               91        Medium      Public                    No
# 3               98        Medium      Public                    No
# 4               65        Medium      Public                    No
#
#   Parental_Education_Level Distance_from_Home  Gender  Exam_Score
# 0              High School               Near    Male          67
# 1                  College           Moderate  Female          61
# 2             Postgraduate               Near    Male          74
# 3              High School           Moderate    Male          71
# 4                  College               Near  Female          70

# %%
df.isnull().sum()
# Out:
# Hours_Studied                0
# Attendance                   0
# Parental_Involvement         0
# Sleep_Hours                  0
# Previous_Scores              0
# Family_Income                0
# School_Type                  0
# Learning_Disabilities        0
# Parental_Education_Level    90
# Distance_from_Home          67
# Gender                       0
# Exam_Score                   0
# dtype: int64

# %%
import seaborn as sns # Hours_Studied, Exam_score
sns.boxplot(df["Exam_Score"])
# Out:
# <Axes: ylabel='Exam_Score'>

# %%
q1 = df.describe()["Hours_Studied"]["25%"]
q3 = df.describe()["Hours_Studied"]["75%"]
iqr = q3 - q1
lower_limit = q1 -1.5 * iqr
upper_limit = q3 + 1.5 * iqr

# %%
df["Hours_Studied"].clip(lower_limit,upper_limit, inplace=True)
# Out:
# C:\Users\Akshitha\AppData\Local\Temp\ipykernel_22548\1687344623.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Hours_Studied"].clip(lower_limit,upper_limit, inplace=True)

# %%
sns.boxplot(df["Hours_Studied"])
# Out:
# <Axes: ylabel='Hours_Studied'>

# %%
q1 = df.describe()["Exam_Score"]["25%"]
q3 = df.describe()["Exam_Score"]["75%"]
iqr = q3 - q1
lower_limit = q1 - 1.5 * iqr
upper_limit = q3 + 1.5 * iqr

# %%
df["Exam_Score"].clip(lower_limit,upper_limit, inplace=True)
# Out:
# C:\Users\Akshitha\AppData\Local\Temp\ipykernel_22548\970302717.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Exam_Score"].clip(lower_limit,upper_limit, inplace=True)

# %%
sns.boxplot(df["Exam_Score"])
# Out:
# <Axes: ylabel='Exam_Score'>

# %%
df.head()
# Out:
#    Hours_Studied  Attendance Parental_Involvement  Sleep_Hours  \
# 0             23          84                  Low            7
# 1             19          64                  Low            8
# 2             24          98               Medium            7
# 3             29          89                  Low            8
# 4             19          92               Medium            6
#
#    Previous_Scores Family_Income School_Type Learning_Disabilities  \
# 0               73           Low      Public                    No
# 1               59        Medium      Public                    No
# 2               91        Medium      Public                    No
# 3               98        Medium      Public                    No
# 4               65        Medium      Public                    No
#
#   Parental_Education_Level Distance_from_Home  Gender  Exam_Score
# 0              High School               Near    Male          67
# 1                  College           Moderate  Female          61
# 2             Postgraduate               Near    Male          74
# 3              High School           Moderate    Male          71
# 4                  College               Near  Female          70

# %%
df.drop(columns=["Parental_Involvement"], inplace=True)

# %%
df.head()
# Out:
#    Hours_Studied  Attendance  Sleep_Hours  Previous_Scores Family_Income  \
# 0             23          84            7               73           Low
# 1             19          64            8               59        Medium
# 2             24          98            7               91        Medium
# 3             29          89            8               98        Medium
# 4             19          92            6               65        Medium
#
#   School_Type Learning_Disabilities Parental_Education_Level  \
# 0      Public                    No              High School
# 1      Public                    No                  College
# 2      Public                    No             Postgraduate
# 3      Public                    No              High School
# 4      Public                    No                  College
#
#   Distance_from_Home  Gender  Exam_Score
# 0               Near    Male          67
# 1           Moderate  Female          61
# 2               Near    Male          74
# 3           Moderate    Male          71
# 4               Near  Female          70

# %%
df.drop(columns=["Learning_Disabilities", "Parental_Education_Level", "Distance_from_Home"], inplace=True, errors='ignore')

# %%
df["Family_Income"].value_counts()
# Out:
# Family_Income
# Low       2672
# Medium    2666
# High      1269
# Name: count, dtype: int64

# %%
d1 = {"Low":0, "Medium":1, "High":2}
df["Family_Income"] = df["Family_Income"].map(d1)

# %%
df["School_Type"].value_counts()
# Out:
# School_Type
# Public     4598
# Private    2009
# Name: count, dtype: int64

# %%
d2 = {"Public":0, "Private":1}
df["School_Type"] = df["School_Type"].map(d2)

# %%
d3 = {"Male":0, "Female":1}
df["Gender"] = df["Gender"].map(d3)

# %%
df.head()
# Out:
#    Hours_Studied  Attendance  Sleep_Hours  Previous_Scores  Family_Income  \
# 0             23          84            7               73              0
# 1             19          64            8               59              1
# 2             24          98            7               91              1
# 3             29          89            8               98              1
# 4             19          92            6               65              1
#
#    School_Type  Gender  Exam_Score
# 0            0       0          67
# 1            0       1          61
# 2            0       0          74
# 3            0       0          71
# 4            0       1          70

# %%
x = df.drop(columns=["Exam_Score"])
y = df["Exam_Score"]

# %%
x.head()
# Out:
#    Hours_Studied  Attendance  Sleep_Hours  Previous_Scores  Family_Income  \
# 0             23          84            7               73              0
# 1             19          64            8               59              1
# 2             24          98            7               91              1
# 3             29          89            8               98              1
# 4             19          92            6               65              1
#
#    School_Type  Gender
# 0            0       0
# 1            0       1
# 2            0       0
# 3            0       0
# 4            0       1

# %%
y.head()
# Out:
# 0    67
# 1    61
# 2    74
# 3    71
# 4    70
# Name: Exam_Score, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2, random_state=0)

# %%
x_train.shape
# Out:
# (5285, 7)

# %%
x_test.shape
# Out:
# (1322, 7)

# %%
y_train.shape
# Out:
# (5285,)

# %%
y_test.shape
# Out:
# (1322,)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)

# %%
y_pred
# Out:
# array([69.39650808, 64.42874369, 67.62063035, ..., 65.72702469,
#        65.30353013, 62.19319038])

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test,y_pred)

# %%
mse
# Out:
# np.float64(3.0087520875849827)

# %%
rmse = np.sqrt(mse)

# %%
rmse
# Out:
# np.float64(1.7345754776270137)

# %%
# %%capture
pip install joblib

# %%
import joblib
joblib.dump(lr, "Exam_Score.pkl")
# Out:
# ['Exam_Score.pkl']

# %%
# %%capture
pip install streamlit

# %%
df.head()
# Out:
#    Hours_Studied  Attendance  Sleep_Hours  Previous_Scores  Family_Income  \
# 0             23          84            7               73              0
# 1             19          64            8               59              1
# 2             24          98            7               91              1
# 3             29          89            8               98              1
# 4             19          92            6               65              1
#
#    School_Type  Gender  Exam_Score
# 0            0       0          67
# 1            0       1          61
# 2            0       0          74
# 3            0       0          71
# 4            0       1          70
